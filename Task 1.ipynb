# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("AirQuality.csv",sep = ';')

# %%
df.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Unnamed: 15  Unnamed: 16
# ...

# %%
df.info()
print("----------------------------------------------------------------")
print("Total Null values per column :-\n",df.isna().sum())
print("----------------------------------------------------------------")
print("Shape of the dataset = ",df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   object
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   object
#  13  RH             9357 non-null   object
#  14  AH             9357 non-null   object
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
# ...

# %%
#Since all the values of these columns are missing, simply drop them
df.drop(['Unnamed: 15', 'Unnamed: 16'],axis= 1, inplace = True)
df.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH
# 0  0,7578
# 1  0,7255
# 2  0,7502
# 3  0,7867
# ...

# %%
df.tail(115)
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 9356  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
# 9357         NaN       NaN    NaN          NaN       NaN      NaN
# 9358         NaN       NaN    NaN          NaN       NaN      NaN
# 9359         NaN       NaN    NaN          NaN       NaN      NaN
# 9360         NaN       NaN    NaN          NaN       NaN      NaN
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9356         1047.0    265.0         654.0    168.0        1129.0
# ...

# %%
df.dropna(inplace = True)

# %%
df.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH
# 0  0,7578
# 1  0,7255
# 2  0,7502
# 3  0,7867
# ...

# %%
def remove_comma(col):
    df[col] = df[col].str.replace(',','.')
cols = ['CO(GT)','C6H6(GT)','T','RH','AH']
for col in cols:
    remove_comma(col)

# %%
df.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2.6       1360.0     150.0     11.9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9.4          955.0
# 2  10/03/2004  20.00.00    2.2       1402.0      88.0      9.0          939.0
# 3  10/03/2004  21.00.00    2.2       1376.0      80.0      9.2          948.0
# 4  10/03/2004  22.00.00    1.6       1272.0      51.0      6.5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13.6  48.9
# 1    103.0        1174.0     92.0        1559.0        972.0  13.3  47.7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11.9  54.0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11.0  60.0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11.2  59.6
#
#        AH
# 0  0.7578
# 1  0.7255
# 2  0.7502
# 3  0.7867
# ...

# %%
df['Time'].unique()
# Out:
# array(['18.00.00', '19.00.00', '20.00.00', '21.00.00', '22.00.00',
#        '23.00.00', '00.00.00', '01.00.00', '02.00.00', '03.00.00',
#        '04.00.00', '05.00.00', '06.00.00', '07.00.00', '08.00.00',
#        '09.00.00', '10.00.00', '11.00.00', '12.00.00', '13.00.00',
#        '14.00.00', '15.00.00', '16.00.00', '17.00.00'], dtype=object)

# %%
df['Time'] = df['Time'].apply(lambda x: int(x.split('.')[0]))
df['Month'] = df['Date'].apply(lambda x: int(x.split('/')[1]))
df['Day'] = df['Date'].apply(lambda x: int(x.split('/')[0]))

# %%
df.drop("Date",axis = 1,inplace = True)

# %%
df.head()
# Out:
#    Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0    18    2.6       1360.0     150.0     11.9         1046.0    166.0
# 1    19      2       1292.0     112.0      9.4          955.0    103.0
# 2    20    2.2       1402.0      88.0      9.0          939.0    131.0
# 3    21    2.2       1376.0      80.0      9.2          948.0    172.0
# 4    22    1.6       1272.0      51.0      6.5          836.0    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  \
# 0        1056.0    113.0        1692.0       1268.0  13.6  48.9  0.7578
# 1        1174.0     92.0        1559.0        972.0  13.3  47.7  0.7255
# 2        1140.0    114.0        1555.0       1074.0  11.9  54.0  0.7502
# 3        1092.0    122.0        1584.0       1203.0  11.0  60.0  0.7867
# 4        1205.0    116.0        1490.0       1110.0  11.2  59.6  0.7888
#
#    Month  Day
# 0      3   10
# 1      3   10
# 2      3   10
# 3      3   10
# 4      3   10

# %%
df.dtypes
# Out:
# Time               int64
# CO(GT)            object
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)          object
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                 object
# RH                object
# AH                object
# Month              int64
# Day                int64
# dtype: object

# %%
cols = ['CO(GT)','C6H6(GT)','T','RH','AH']
for col in cols:
    df[col] = df[col].astype(float)

# %%
df.head()
# Out:
#    Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0    18     2.6       1360.0     150.0      11.9         1046.0    166.0
# 1    19     2.0       1292.0     112.0       9.4          955.0    103.0
# 2    20     2.2       1402.0      88.0       9.0          939.0    131.0
# 3    21     2.2       1376.0      80.0       9.2          948.0    172.0
# 4    22     1.6       1272.0      51.0       6.5          836.0    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  \
# 0        1056.0    113.0        1692.0       1268.0  13.6  48.9  0.7578
# 1        1174.0     92.0        1559.0        972.0  13.3  47.7  0.7255
# 2        1140.0    114.0        1555.0       1074.0  11.9  54.0  0.7502
# 3        1092.0    122.0        1584.0       1203.0  11.0  60.0  0.7867
# 4        1205.0    116.0        1490.0       1110.0  11.2  59.6  0.7888
#
#    Month  Day
# 0      3   10
# 1      3   10
# 2      3   10
# 3      3   10
# 4      3   10

# %%
df.describe()
# Out:
#               Time       CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000  9357.000000
# mean     11.498557   -34.207524  1048.990061  -159.090093     1.865683
# std       6.923182    77.657170   329.832710   139.789093    41.380206
# min       0.000000  -200.000000  -200.000000  -200.000000  -200.000000
# 25%       5.000000     0.600000   921.000000  -200.000000     4.000000
# 50%      11.000000     1.500000  1053.000000  -200.000000     7.900000
# 75%      18.000000     2.600000  1221.000000  -200.000000    13.600000
# max      23.000000    11.900000  2040.000000  1189.000000    63.700000
#
#        PT08.S2(NMHC)      NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  \
# count    9357.000000  9357.000000   9357.000000  9357.000000   9357.000000
# mean      894.595276   168.616971    794.990168    58.148873   1391.479641
# std       342.333252   257.433866    321.993552   126.940455    467.210125
# ...

# %%
df.dtypes
# Out:
# Time               int64
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# Month              int64
# Day                int64
# dtype: object

# %%
plt.figure(figsize = (15,8))
df.boxplot()
# Out:
# <AxesSubplot: >

# %%
for col in df.columns[2:]:
    if col != 'NMHC(GT)':
        Q1 = df[col].sort_values().quantile(0.25)
        Q3 = df[col].sort_values().quantile(0.75)
        IQR = Q3-Q1
        df = df[~((df[col]<(Q1-1.5*IQR)) | (df[col]>(Q3+1.5*IQR)))]

# %%
plt.figure(figsize = (15,8))
df.boxplot()
# Out:
# <AxesSubplot: >

# %%
df.head()
# Out:
#    Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0    18     2.6       1360.0     150.0      11.9         1046.0    166.0
# 1    19     2.0       1292.0     112.0       9.4          955.0    103.0
# 2    20     2.2       1402.0      88.0       9.0          939.0    131.0
# 3    21     2.2       1376.0      80.0       9.2          948.0    172.0
# 4    22     1.6       1272.0      51.0       6.5          836.0    131.0
#
#    PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH  \
# 0        1056.0    113.0        1692.0       1268.0  13.6  48.9  0.7578
# 1        1174.0     92.0        1559.0        972.0  13.3  47.7  0.7255
# 2        1140.0    114.0        1555.0       1074.0  11.9  54.0  0.7502
# 3        1092.0    122.0        1584.0       1203.0  11.0  60.0  0.7867
# 4        1205.0    116.0        1490.0       1110.0  11.2  59.6  0.7888
#
#    Month  Day
# 0      3   10
# 1      3   10
# 2      3   10
# 3      3   10
# 4      3   10

# %%
plt.figure(figsize = (13,10))
sns.heatmap(df.corr(),annot = True,cmap = 'viridis')
# Out:
# <AxesSubplot: >

# %%
#Checking how target variable(RH) is related to the rest of the columns
for col in df.columns[2:]:
    sns.lmplot(x = col, y = 'RH', data = df,markers = '.')

# %%
X = df.drop('RH',axis = 1)
Y = df['RH']

# %%
for col in X.columns[2:]:
    X[col].plot(kind = 'kde')
    plt.title(col)
    plt.show()

#There is a need to standardize the data

# %%
ss = StandardScaler()
X_std = ss.fit_transform(X)

# %%
#This is a linear regression problem as the values are continuous
#To deal with this problem we can use linear regression model or xgbregressor model
